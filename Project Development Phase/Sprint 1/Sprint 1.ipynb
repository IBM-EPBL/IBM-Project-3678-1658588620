# %%
# importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the Datasets
data=pd.read_csv('/content/drive/MyDrive/Datasets/chronickidneydisease.csv')

# %%
# information of the datasets
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
# shape of the dataset
data.shape
# Out:
# (400, 26)

# %%
#  tocheck the Columns of dataset
data.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
# unique features
data.nunique()
# Out:
# id                400
# age                76
# bp                 10
# sg                  5
# al                  6
# su                  6
# rbc                 2
# pc                  2
# pcc                 2
# ba                  2
# bgr               146
# bu                118
# sc                 84
# sod                34
# pot                40
# hemo              115
# pcv                44
# wc                 92
# rc                 49
# htn                 2
# dm                  5
# cad                 3
# appet               2
# pe                  2
# ane                 2
# classification      3
# dtype: int64

# %%
# unique feature of age
data['age'].unique()
# Out:
# array([48.,  7., 62., 51., 60., 68., 24., 52., 53., 50., 63., 40., 47.,
#        61., 21., 42., 75., 69., nan, 73., 70., 65., 76., 72., 82., 46.,
#        45., 35., 54., 11., 59., 67., 15., 55., 44., 26., 64., 56.,  5.,
#        74., 38., 58., 71., 34., 17., 12., 43., 41., 57.,  8., 39., 66.,
#        81., 14., 27., 83., 30.,  4.,  3.,  6., 32., 80., 49., 90., 78.,
#        19.,  2., 33., 36., 37., 23., 25., 20., 29., 28., 22., 79.])

# %%
# unique feature of bgr
data['bgr'].unique()
# Out:
# array([121.,  nan, 423., 117., 106.,  74., 100., 410., 138.,  70., 490.,
#        380., 208.,  98., 157.,  76.,  99., 114., 263., 173.,  95., 108.,
#        156., 264., 123.,  93., 107., 159., 140., 171., 270.,  92., 137.,
#        204.,  79., 207., 124., 144.,  91., 162., 246., 253., 141., 182.,
#         86., 150., 146., 425., 112., 250., 360., 163., 129., 133., 102.,
#        158., 165., 132., 104., 127., 415., 169., 251., 109., 280., 210.,
#        219., 295.,  94., 172., 101., 298., 153.,  88., 226., 143., 115.,
#         89., 297., 233., 294., 323., 125.,  90., 308., 118., 224., 128.,
#        122., 214., 213., 268., 256.,  84., 105., 288., 139.,  78., 273.,
#        242., 424., 303., 148., 160., 192., 307., 220., 447., 309.,  22.,
#        111., 261., 215., 234., 131., 352.,  80., 239., 110., 130., 184.,
#        252., 113., 230., 341., 255., 103., 238., 248., 120., 241., 269.,
#        201., 203., 463., 176.,  82., 119.,  97.,  96.,  81., 116., 134.,
# ...

# %%
# unique feature of bp
data['bp'].unique()
# Out:
# array([ 80.,  50.,  70.,  90.,  nan, 100.,  60., 110., 140., 180., 120.])

# %%
# checking the missing value
data.isna()
# Out:
#         id    age     bp     sg     al     su    rbc     pc    pcc     ba  \
# 0    False  False  False  False  False  False   True  False  False  False
# 1    False  False  False  False  False  False   True  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 395  False  False  False  False  False  False  False  False  False  False
# 396  False  False  False  False  False  False  False  False  False  False
# 397  False  False  False  False  False  False  False  False  False  False
# 398  False  False  False  False  False  False  False  False  False  False
# 399  False  False  False  False  False  False  False  False  False  False
#
#      ...    pcv     wc     rc    htn     dm    cad  appet     pe    ane  \
# ...

# %%
data.isna().any()
# Out:
# id                False
# age                True
# bp                 True
# sg                 True
# al                 True
# su                 True
# rbc                True
# pc                 True
# pcc                True
# ba                 True
# bgr                True
# bu                 True
# sc                 True
# sod                True
# pot                True
# hemo               True
# pcv                True
# wc                 True
# rc                 True
# htn                True
# dm                 True
# cad                True
# appet              True
# pe                 True
# ane                True
# classification    False
# dtype: bool

# %%
data.isna().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
# statistical analysis of data
data.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %%
data.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# ...

# %%
data.median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# ...

# %%
data.shape
# Out:
# (400, 26)

# %%
# correlation in the data
data.corr()
# Out:
#             id       age        bp        sg        al        su       bgr  \
# id    1.000000 -0.185308 -0.245744  0.642156 -0.541993 -0.283416 -0.338673
# age  -0.185308  1.000000  0.159480 -0.191096  0.122091  0.220866  0.244992
# bp   -0.245744  0.159480  1.000000 -0.218836  0.160689  0.222576  0.160193
# sg    0.642156 -0.191096 -0.218836  1.000000 -0.469760 -0.296234 -0.374710
# al   -0.541993  0.122091  0.160689 -0.469760  1.000000  0.269305  0.379464
# su   -0.283416  0.220866  0.222576 -0.296234  0.269305  1.000000  0.717827
# bgr  -0.338673  0.244992  0.160193 -0.374710  0.379464  0.717827  1.000000
# bu   -0.307175  0.196985  0.188517 -0.314295  0.453528  0.168583  0.143322
# sc   -0.268683  0.132531  0.146222 -0.361473  0.399198  0.223244  0.114875
# sod   0.364251 -0.100046 -0.116422  0.412190 -0.459896 -0.131776 -0.267848
# pot  -0.092347  0.058377  0.075151 -0.072787  0.129038  0.219450  0.066966
# ...

# %%
# duplicate values in dataset
data.duplicated().sum()
# Out:
# 0

# %%
# to show in row format
data.describe().T
# Out:
#       count        mean         std     min     25%     50%     75%      max
# id    400.0  199.500000  115.614301   0.000   99.75  199.50  299.25  399.000
# age   391.0   51.483376   17.169714   2.000   42.00   55.00   64.50   90.000
# bp    388.0   76.469072   13.683637  50.000   70.00   80.00   80.00  180.000
# sg    353.0    1.017408    0.005717   1.005    1.01    1.02    1.02    1.025
# al    354.0    1.016949    1.352679   0.000    0.00    0.00    2.00    5.000
# su    351.0    0.450142    1.099191   0.000    0.00    0.00    0.00    5.000
# bgr   356.0  148.036517   79.281714  22.000   99.00  121.00  163.00  490.000
# bu    381.0   57.425722   50.503006   1.500   27.00   42.00   66.00  391.000
# sc    383.0    3.072454    5.741126   0.400    0.90    1.30    2.80   76.000
# sod   313.0  137.528754   10.408752   4.500  135.00  138.00  142.00  163.000
# pot   312.0    4.627244    3.193904   2.500    3.80    4.40    4.90   47.000
# ...

# %%
# 
data.dropna()
# Out:
#       id   age    bp     sg   al   su       rbc        pc         pcc  \
# 3      3  48.0  70.0  1.005  4.0  0.0    normal  abnormal     present
# 9      9  53.0  90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 11    11  63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present
# 14    14  68.0  80.0  1.010  3.0  2.0    normal  abnormal     present
# 20    20  61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent
# ..   ...   ...   ...    ...  ...  ...       ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0    normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0    normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0    normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0    normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0    normal    normal  notpresent
#
#              ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# ...

# %%
#data visulization heatmap
sns.heatmap(data.corr(),annot=True)

# %%
#histogram
data['age'].plot(kind='hist')

# %%
# listplot
df=pd.DataFrame(data)
X=list(df.iloc[:,0])
Y=list(df.iloc[:,1])
plt.bar(X,Y,color='g')
# Out:
# <BarContainer object of 400 artists>

# %%
# line plot
sns.lineplot(data['age'],data['bp'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# the outliers and replace the outliers
sns.boxplot(data['age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
qnt=data.quantile(q=[0.25,0.75])
qnt
# Out:
#           id   age    bp    sg   al   su    bgr    bu   sc    sod  pot  hemo
# 0.25   99.75  42.0  70.0  1.01  0.0  0.0   99.0  27.0  0.9  135.0  3.8  10.3
# 0.75  299.25  64.5  80.0  1.02  2.0  0.0  163.0  66.0  2.8  142.0  4.9  15.0

# %%
IQR=qnt.loc[0.75] - qnt.loc[0.25]
IQR
# Out:
# id      199.50
# age      22.50
# bp       10.00
# sg        0.01
# al        2.00
# su        0.00
# bgr      64.00
# bu       39.00
# sc        1.90
# sod       7.00
# pot       1.10
# hemo      4.70
# dtype: float64

# %%
upper_extreme=qnt.loc[0.75]+1.5*IQR
upper_extreme
# Out:
# id      598.500
# age      98.250
# bp       95.000
# sg        1.035
# al        5.000
# su        0.000
# bgr     259.000
# bu      124.500
# sc        5.650
# sod     152.500
# pot       6.550
# hemo     22.050
# dtype: float64

# %%
lower_extreme=qnt.loc[0.25]-1.5*IQR
lower_extreme
# Out:
# id     -199.500
# age       8.250
# bp       55.000
# sg        0.995
# al       -3.000
# su        0.000
# bgr       3.000
# bu      -31.500
# sc       -1.950
# sod     124.500
# pot       2.150
# hemo      3.250
# dtype: float64

# %%
df=data[(data['age']<upper_extreme['age'])&(data['age']>lower_extreme['age'])]

# %%
data.shape
# Out:
# (400, 26)

# %%
sns.boxplot(df['age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# check for categorical columns and perform encoding
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df['bgr']=le.fit_transform(df['bgr'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.head()
# Out:
#    id   age  bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0   3  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0   3  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0   2  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0   3  1.010  2.0  0.0  normal    normal  notpresent  notpresent
# 5   5  60.0   4  1.015  3.0  0.0     NaN       NaN  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
# 5  ...   39  7800  4.4  yes  yes   no  good  yes   no            ckd
#
# [5 rows x 26 columns]

# %%
# scaling the data
from sklearn.preprocessing import scale
x=df.iloc[:1,2]
y=df.iloc[:,2]

# %%
x=data.drop(columns=['rbc'],axis=1)
x.head()
# Out:
#    id   age    bp     sg   al   su        pc         pcc          ba    bgr  \
# 0   0  48.0  80.0  1.020  1.0  0.0    normal  notpresent  notpresent  121.0
# 1   1   7.0  50.0  1.020  4.0  0.0    normal  notpresent  notpresent    NaN
# 2   2  62.0  80.0  1.010  2.0  3.0    normal  notpresent  notpresent  423.0
# 3   3  48.0  70.0  1.005  4.0  0.0  abnormal     present  notpresent  117.0
# 4   4  51.0  80.0  1.010  2.0  0.0    normal  notpresent  notpresent  106.0
#
#    ...  pcv    wc   rc  htn   dm cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes  no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no  no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes  no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no  no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no  no  good   no   no            ckd
#
# [5 rows x 25 columns]

# %%
names = x.columns
names
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
x.head
# Out:
# <bound method NDFrame.head of       id   age    bp     sg   al   su        pc         pcc          ba  \
# 0      0  48.0  80.0  1.020  1.0  0.0    normal  notpresent  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0    normal  notpresent  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0    normal  notpresent  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  abnormal     present  notpresent
# 4      4  51.0  80.0  1.010  2.0  0.0    normal  notpresent  notpresent
# ..   ...   ...   ...    ...  ...  ...       ...         ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0    normal  notpresent  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0    normal  notpresent  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0    normal  notpresent  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0    normal  notpresent  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0    normal  notpresent  notpresent
#
# ...

# %%
# split the data into depandent and independent variables
x=df['rbc']
y=df.drop(columns=['rbc'],axis=1)

# %%
x.head()
# Out:
# 0       NaN
# 2    normal
# 3    normal
# 4    normal
# 5       NaN
# Name: rbc, dtype: object

# %%
y.head()
# Out:
#    id   age  bp     sg   al   su        pc         pcc          ba  bgr  ...  \
# 0   0  48.0   3  1.020  1.0  0.0    normal  notpresent  notpresent   48  ...
# 2   2  62.0   3  1.010  2.0  3.0    normal  notpresent  notpresent  139  ...
# 3   3  48.0   2  1.005  4.0  0.0  abnormal     present  notpresent   44  ...
# 4   4  51.0   3  1.010  2.0  0.0    normal  notpresent  notpresent   33  ...
# 5   5  60.0   4  1.015  3.0  0.0       NaN  notpresent  notpresent    2  ...
#
#    pcv    wc   rc  htn   dm cad appet   pe  ane classification
# 0   44  7800  5.2  yes  yes  no  good   no   no            ckd
# 2   31  7500  NaN   no  yes  no  poor   no  yes            ckd
# 3   32  6700  3.9  yes   no  no  poor  yes  yes            ckd
# 4   35  7300  4.6   no   no  no  good   no   no            ckd
# 5   39  7800  4.4  yes  yes  no  good  yes   no            ckd
#
# [5 rows x 25 columns]

# %%
# the data into trainig and testing
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
# 309         NaN
# 301      normal
# 331      normal
# 82          NaN
# 193    abnormal
#          ...
# 88          NaN
# 93     abnormal
# 294      normal
# 99          NaN
# 230      normal
# Name: rbc, Length: 304, dtype: object

# %%
x_train.shape
# Out:
# (304,)

# %%
x_test
# Out:
# 397      normal
# 364      normal
# 257      normal
# 213      normal
# 96          NaN
#          ...
# 91     abnormal
# 365      normal
# 253      normal
# 377      normal
# 212      normal
# Name: rbc, Length: 77, dtype: object

# %%
x_test.shape
# Out:
# (77,)

# %%
y_train
# Out:
#       id   age  bp     sg   al   su        pc         pcc          ba  bgr  \
# 309  309  51.0   1  1.020  0.0  0.0       NaN  notpresent  notpresent   55
# 301  301  44.0   1  1.025  0.0  0.0    normal  notpresent  notpresent   23
# 331  331  59.0   2  1.025  0.0  0.0    normal  notpresent  notpresent   56
# 82    82  38.0   2    NaN  NaN  NaN       NaN  notpresent  notpresent   31
# 193  193  32.0   4  1.025  1.0  0.0  abnormal  notpresent  notpresent  145
# ..   ...   ...  ..    ...  ...  ...       ...         ...         ...  ...
# 88    88  58.0   6  1.010  4.0  0.0    normal  notpresent  notpresent  110
# 93    93  73.0   5  1.010  3.0  2.0  abnormal     present  notpresent  125
# 294  294  75.0   1  1.020  0.0  0.0    normal  notpresent  notpresent   37
# 99    99  56.0   9    NaN  0.0  4.0  abnormal  notpresent  notpresent  127
# 230  230  65.0   1  1.010  2.0  0.0  abnormal     present  notpresent   87
#
# ...

# %%
y_train.shape
# Out:
# (304, 25)

# %%
y_test
# Out:
#       id   age  bp     sg   al   su        pc         pcc          ba  bgr  \
# 397  397  12.0   3  1.020  0.0  0.0    normal  notpresent  notpresent   27
# 364  364  73.0   3  1.025  0.0  0.0    normal  notpresent  notpresent   45
# 257  257  38.0   1  1.020  0.0  0.0    normal  notpresent  notpresent   18
# 213  213  55.0   3  1.010  3.0  1.0  abnormal     present     present   95
# 96    96  60.0   3  1.010  1.0  1.0    normal  notpresent  notpresent   82
# ..   ...   ...  ..    ...  ...  ...       ...         ...         ...  ...
# 91    91  56.0   2  1.015  4.0  1.0    normal  notpresent  notpresent   93
# 365  365  24.0   3  1.020  0.0  0.0    normal  notpresent  notpresent   20
# 253  253  57.0   3  1.025  0.0  0.0    normal  notpresent  notpresent   46
# 377  377  64.0   2  1.020  0.0  0.0    normal  notpresent  notpresent   24
# 212  212  40.0   2  1.015  3.0  4.0    normal  notpresent  notpresent  112
#
# ...

# %%
y_test.shape
# Out:
# (77, 25)
